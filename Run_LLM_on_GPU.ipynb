# %%
# !curl -fsSL https://ollama.com/install.sh | sh
# Out:
# >>> Cleaning up old version at /usr/local/lib/ollama
# >>> Installing ollama to /usr/local
# >>> Downloading Linux amd64 bundle
# ######################################################################## 100.0%
# >>> Adding ollama user to video group...
# >>> Adding current user to ollama group...
# >>> Creating ollama systemd service...
# WARNING: systemd is not running
# WARNING: Unable to detect NVIDIA/AMD GPU. Install lspci or lshw to automatically detect and install GPU dependencies.
# >>> The Ollama API is now available at 127.0.0.1:11434.
# >>> Install complete. Run "ollama" from the command line.

# %%
# run the following command on terminal
#ollama serve

# %%
# !ollama pull gpt-oss:20b

# %%
# !ollama list
# Out:
# NAME           ID              SIZE     MODIFIED
# gpt-oss:20b    aa4295ac10c3    13 GB    2 minutes ago

# %%
# !curl -sSL https://ngrok-agent.s3.amazonaws.com/ngrok.asc \
  | sudo tee /etc/apt/trusted.gpg.d/ngrok.asc >/dev/null \
  && echo "deb https://ngrok-agent.s3.amazonaws.com bookworm main" \
  | sudo tee /etc/apt/sources.list.d/ngrok.list \
  && sudo apt update \
  && sudo apt install ngrok
# Out:
# deb https://ngrok-agent.s3.amazonaws.com bookworm main
# Hit:1 https://cli.github.com/packages stable InRelease
# Hit:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:4 https://ngrok-agent.s3.amazonaws.com bookworm InRelease
# Hit:5 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Hit:6 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Hit:7 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:8 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:9 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:10 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:11 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:12 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# 41 packages can be upgraded. Run 'apt list --upgradable' to see them.
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# ngrok is already the newest version (3.30.0).
# 0 upgraded, 0 newly installed, 0 to remove and 41 not upgraded.

# %%
# get your token on ngrok and add it to secret as NGROK

# %%
# !ngrok config add-authtoken <YOUR_TOKEN_HERE>
# Out:
# Authtoken saved to configuration file: /root/.config/ngrok/ngrok.yml

# %%
# run the following in terminal
#ngrok http 11434

# %%
# !OLLAMA_HOST=0.0.0.0 OLLAMA_ORIGINS=https://b52fa22614ec.ngrok-free.app/* ollama serve
# Out:
# time=2025-09-24T17:48:34.089Z level=INFO source=routes.go:1475 msg="server config" env="map[CUDA_VISIBLE_DEVICES: GPU_DEVICE_ORDINAL: HIP_VISIBLE_DEVICES: HSA_OVERRIDE_GFX_VERSION: HTTPS_PROXY: HTTP_PROXY: NO_PROXY: OLLAMA_CONTEXT_LENGTH:4096 OLLAMA_DEBUG:INFO OLLAMA_FLASH_ATTENTION:false OLLAMA_GPU_OVERHEAD:0 OLLAMA_HOST:http://0.0.0.0:11434 OLLAMA_INTEL_GPU:false OLLAMA_KEEP_ALIVE:5m0s OLLAMA_KV_CACHE_TYPE: OLLAMA_LLM_LIBRARY: OLLAMA_LOAD_TIMEOUT:5m0s OLLAMA_MAX_LOADED_MODELS:0 OLLAMA_MAX_QUEUE:512 OLLAMA_MODELS:/root/.ollama/models OLLAMA_MULTIUSER_CACHE:false OLLAMA_NEW_ENGINE:false OLLAMA_NOHISTORY:false OLLAMA_NOPRUNE:false OLLAMA_NUM_PARALLEL:1 OLLAMA_ORIGINS:[https://b52fa22614ec.ngrok-free.app/* http://localhost https://localhost http://localhost:* https://localhost:* http://127.0.0.1 https://127.0.0.1 http://127.0.0.1:* https://127.0.0.1:* http://0.0.0.0 https://0.0.0.0 http://0.0.0.0:* https://0.0.0.0:* app://* file://* tauri://* vscode-webview://* vscode-file://*] OLLAMA_REMOTES:[ollama.com] OLLAMA_SCHED_SPREAD:false ROCR_VISIBLE_DEVICES: http_proxy: https_proxy: no_proxy:]"
# time=2025-09-24T17:48:34.090Z level=INFO source=images.go:518 msg="total blobs: 5"
# time=2025-09-24T17:48:34.090Z level=INFO source=images.go:525 msg="total unused blobs removed: 0"
# time=2025-09-24T17:48:34.090Z level=INFO source=routes.go:1528 msg="Listening on [::]:11434 (version 0.12.1)"
# time=2025-09-24T17:48:34.090Z level=INFO source=gpu.go:217 msg="looking for compatible GPUs"
# time=2025-09-24T17:48:34.272Z level=WARN source=cuda_common.go:60 msg="old CUDA driver detected - please upgrade to a newer driver for best performance" version=12.4
# time=2025-09-24T17:48:34.272Z level=INFO source=types.go:131 msg="inference compute" id=GPU-2e16d61d-883d-178d-58d1-70d1b8c22d1e library=cuda variant=v12 compute=7.5 driver=12.4 name="Tesla T4" total="14.7 GiB" available="14.6 GiB"
# time=2025-09-24T17:48:34.272Z level=INFO source=routes.go:1569 msg="entering low vram mode" "total vram"="14.7 GiB" threshold="20.0 GiB"
# [GIN] 2025/09/24 - 17:48:39 | 200 |      80.358µs |  105.67.129.157 | GET      "/"
# [GIN] 2025/09/24 - 17:48:40 | 404 |       7.867µs |  105.67.129.157 | GET      "/favicon.ico"
# [GIN] 2025/09/24 - 17:48:55 | 404 |       8.967µs |  105.67.129.157 | GET      "/v1/tags"
# [GIN] 2025/09/24 - 17:49:05 | 200 |     792.564µs |  105.67.129.157 | GET      "/api/tags"
# [GIN] 2025/09/24 - 17:51:28 | 404 |    4.283695ms |  184.73.225.134 | POST     "/v1/chat/completions"
# time=2025-09-24T17:51:45.909Z level=INFO source=server.go:200 msg="model wants flash attention"
# time=2025-09-24T17:51:45.910Z level=INFO source=server.go:217 msg="enabling flash attention"
# time=2025-09-24T17:51:45.910Z level=INFO source=server.go:399 msg="starting runner" cmd="/usr/local/bin/ollama runner --ollama-engine --model /root/.ollama/models/blobs/sha256-b112e727c6f18875636c56a779790a590d705aec9e1c0eb5a97d51fc2a778583 --port 38795"
# time=2025-09-24T17:51:45.911Z level=INFO source=server.go:672 msg="loading model" "model layers"=25 requested=-1
# time=2025-09-24T17:51:45.940Z level=INFO source=runner.go:1252 msg="starting ollama engine"
# time=2025-09-24T17:51:45.946Z level=INFO source=runner.go:1287 msg="Server listening on 127.0.0.1:38795"
# time=2025-09-24T17:51:46.005Z level=INFO source=server.go:678 msg="system memory" total="12.7 GiB" free="11.4 GiB" free_swap="0 B"
# time=2025-09-24T17:51:46.005Z level=INFO source=server.go:686 msg="gpu memory" id=GPU-2e16d61d-883d-178d-58d1-70d1b8c22d1e available="14.2 GiB" free="14.6 GiB" minimum="457.0 MiB" overhead="0 B"
# time=2025-09-24T17:51:46.006Z level=INFO source=runner.go:1171 msg=load request="{Operation:fit LoraPath:[] Parallel:1 BatchSize:512 FlashAttention:true KvSize:4096 KvCacheType: NumThreads:1 GPULayers:25[ID:GPU-2e16d61d-883d-178d-58d1-70d1b8c22d1e Layers:25(0..24)] MultiUserCache:false ProjectorPath: MainGPU:0 UseMmap:false}"
# time=2025-09-24T17:51:46.092Z level=INFO source=ggml.go:131 msg="" architecture=gptoss file_type=MXFP4 name="" description="" num_tensors=315 num_key_values=30
# load_backend: loaded CPU backend from /usr/local/lib/ollama/libggml-cpu-skylakex.so
# ggml_cuda_init: GGML_CUDA_FORCE_MMQ:    no
# ggml_cuda_init: GGML_CUDA_FORCE_CUBLAS: no
# ggml_cuda_init: found 1 CUDA devices:
#   Device 0: Tesla T4, compute capability 7.5, VMM: yes, ID: GPU-2e16d61d-883d-178d-58d1-70d1b8c22d1e
# load_backend: loaded CUDA backend from /usr/local/lib/ollama/cuda_v12/libggml-cuda.so
# time=2025-09-24T17:51:46.846Z level=INFO source=ggml.go:104 msg=system CPU.0.SSE3=1 CPU.0.SSSE3=1 CPU.0.AVX=1 CPU.0.AVX2=1 CPU.0.F16C=1 CPU.0.FMA=1 CPU.0.BMI2=1 CPU.0.AVX512=1 CPU.0.LLAMAFILE=1 CPU.1.LLAMAFILE=1 CUDA.0.ARCHS=500,600,610,700,750,800,860,870,890,900,1200 CUDA.0.USE_GRAPHS=1 CUDA.0.PEER_MAX_BATCH_SIZE=128 compiler=cgo(gcc)
# time=2025-09-24T17:51:46.960Z level=INFO source=runner.go:1171 msg=load request="{Operation:alloc LoraPath:[] Parallel:1 BatchSize:512 FlashAttention:true KvSize:4096 KvCacheType: NumThreads:1 GPULayers:25[ID:GPU-2e16d61d-883d-178d-58d1-70d1b8c22d1e Layers:25(0..24)] MultiUserCache:false ProjectorPath: MainGPU:0 UseMmap:false}"
# time=2025-09-24T17:51:47.055Z level=INFO source=runner.go:1171 msg=load request="{Operation:commit LoraPath:[] Parallel:1 BatchSize:512 FlashAttention:true KvSize:4096 KvCacheType: NumThreads:1 GPULayers:25[ID:GPU-2e16d61d-883d-178d-58d1-70d1b8c22d1e Layers:25(0..24)] MultiUserCache:false ProjectorPath: MainGPU:0 UseMmap:false}"
# time=2025-09-24T17:51:47.056Z level=INFO source=backend.go:310 msg="model weights" device=CUDA0 size="11.8 GiB"
# time=2025-09-24T17:51:47.056Z level=INFO source=backend.go:315 msg="model weights" device=CPU size="1.1 GiB"
# time=2025-09-24T17:51:47.056Z level=INFO source=backend.go:321 msg="kv cache" device=CUDA0 size="204.0 MiB"
# time=2025-09-24T17:51:47.056Z level=INFO source=backend.go:332 msg="compute graph" device=CUDA0 size="117.8 MiB"
# time=2025-09-24T17:51:47.056Z level=INFO source=backend.go:337 msg="compute graph" device=CPU size="5.6 MiB"
# time=2025-09-24T17:51:47.056Z level=INFO source=backend.go:342 msg="total memory" size="13.2 GiB"
# time=2025-09-24T17:51:47.055Z level=INFO source=ggml.go:487 msg="offloading 24 repeating layers to GPU"
# time=2025-09-24T17:51:47.055Z level=INFO source=ggml.go:493 msg="offloading output layer to GPU"
# time=2025-09-24T17:51:47.055Z level=INFO source=ggml.go:498 msg="offloaded 25/25 layers to GPU"
# time=2025-09-24T17:51:47.056Z level=INFO source=sched.go:470 msg="loaded runners" count=1
# time=2025-09-24T17:51:47.056Z level=INFO source=server.go:1251 msg="waiting for llama runner to start responding"
# time=2025-09-24T17:51:47.057Z level=INFO source=server.go:1285 msg="waiting for server to become available" status="llm server loading model"
# time=2025-09-24T17:52:40.592Z level=INFO source=server.go:1289 msg="llama runner started in 54.68 seconds"
# time=2025-09-24T17:52:40.773Z level=WARN source=runner.go:159 msg="truncating input prompt" limit=4096 prompt=4959 keep=4 new=4096
# [GIN] 2025/09/24 - 17:52:48 | 200 |          1m2s |   52.44.113.131 | POST     "/v1/chat/completions"
# time=2025-09-24T17:53:13.705Z level=WARN source=runner.go:159 msg="truncating input prompt" limit=4096 prompt=4967 keep=4 new=4096
# [GIN] 2025/09/24 - 17:53:34 | 200 | 21.170448314s |  184.73.225.134 | POST     "/v1/chat/completions"
# time=2025-09-24T18:01:29.780Z level=INFO source=server.go:200 msg="model wants flash attention"
# time=2025-09-24T18:01:29.780Z level=INFO source=server.go:217 msg="enabling flash attention"
# time=2025-09-24T18:01:29.780Z level=INFO source=server.go:399 msg="starting runner" cmd="/usr/local/bin/ollama runner --ollama-engine --model /root/.ollama/models/blobs/sha256-b112e727c6f18875636c56a779790a590d705aec9e1c0eb5a97d51fc2a778583 --port 32875"
# time=2025-09-24T18:01:29.781Z level=INFO source=server.go:672 msg="loading model" "model layers"=25 requested=-1
# time=2025-09-24T18:01:29.805Z level=INFO source=runner.go:1252 msg="starting ollama engine"
# time=2025-09-24T18:01:29.809Z level=INFO source=runner.go:1287 msg="Server listening on 127.0.0.1:32875"
# time=2025-09-24T18:01:29.872Z level=INFO source=server.go:678 msg="system memory" total="12.7 GiB" free="11.4 GiB" free_swap="0 B"
# time=2025-09-24T18:01:29.872Z level=INFO source=server.go:686 msg="gpu memory" id=GPU-2e16d61d-883d-178d-58d1-70d1b8c22d1e available="14.2 GiB" free="14.6 GiB" minimum="457.0 MiB" overhead="0 B"
# time=2025-09-24T18:01:29.873Z level=INFO source=runner.go:1171 msg=load request="{Operation:fit LoraPath:[] Parallel:1 BatchSize:512 FlashAttention:true KvSize:4096 KvCacheType: NumThreads:1 GPULayers:25[ID:GPU-2e16d61d-883d-178d-58d1-70d1b8c22d1e Layers:25(0..24)] MultiUserCache:false ProjectorPath: MainGPU:0 UseMmap:false}"
# time=2025-09-24T18:01:29.960Z level=INFO source=ggml.go:131 msg="" architecture=gptoss file_type=MXFP4 name="" description="" num_tensors=315 num_key_values=30
# load_backend: loaded CPU backend from /usr/local/lib/ollama/libggml-cpu-skylakex.so
# ggml_cuda_init: GGML_CUDA_FORCE_MMQ:    no
# ggml_cuda_init: GGML_CUDA_FORCE_CUBLAS: no
# ggml_cuda_init: found 1 CUDA devices:
#   Device 0: Tesla T4, compute capability 7.5, VMM: yes, ID: GPU-2e16d61d-883d-178d-58d1-70d1b8c22d1e
# load_backend: loaded CUDA backend from /usr/local/lib/ollama/cuda_v12/libggml-cuda.so
# time=2025-09-24T18:01:30.249Z level=INFO source=ggml.go:104 msg=system CPU.0.SSE3=1 CPU.0.SSSE3=1 CPU.0.AVX=1 CPU.0.AVX2=1 CPU.0.F16C=1 CPU.0.FMA=1 CPU.0.BMI2=1 CPU.0.AVX512=1 CPU.0.LLAMAFILE=1 CPU.1.LLAMAFILE=1 CUDA.0.ARCHS=500,600,610,700,750,800,860,870,890,900,1200 CUDA.0.USE_GRAPHS=1 CUDA.0.PEER_MAX_BATCH_SIZE=128 compiler=cgo(gcc)
# time=2025-09-24T18:01:30.331Z level=INFO source=runner.go:1171 msg=load request="{Operation:alloc LoraPath:[] Parallel:1 BatchSize:512 FlashAttention:true KvSize:4096 KvCacheType: NumThreads:1 GPULayers:25[ID:GPU-2e16d61d-883d-178d-58d1-70d1b8c22d1e Layers:25(0..24)] MultiUserCache:false ProjectorPath: MainGPU:0 UseMmap:false}"
# time=2025-09-24T18:01:30.426Z level=INFO source=runner.go:1171 msg=load request="{Operation:commit LoraPath:[] Parallel:1 BatchSize:512 FlashAttention:true KvSize:4096 KvCacheType: NumThreads:1 GPULayers:25[ID:GPU-2e16d61d-883d-178d-58d1-70d1b8c22d1e Layers:25(0..24)] MultiUserCache:false ProjectorPath: MainGPU:0 UseMmap:false}"
# time=2025-09-24T18:01:30.427Z level=INFO source=backend.go:310 msg="model weights" device=CUDA0 size="11.8 GiB"
# time=2025-09-24T18:01:30.427Z level=INFO source=backend.go:315 msg="model weights" device=CPU size="1.1 GiB"
# time=2025-09-24T18:01:30.427Z level=INFO source=backend.go:321 msg="kv cache" device=CUDA0 size="204.0 MiB"
# time=2025-09-24T18:01:30.427Z level=INFO source=backend.go:332 msg="compute graph" device=CUDA0 size="117.8 MiB"
# time=2025-09-24T18:01:30.427Z level=INFO source=backend.go:337 msg="compute graph" device=CPU size="5.6 MiB"
# time=2025-09-24T18:01:30.427Z level=INFO source=backend.go:342 msg="total memory" size="13.2 GiB"
# time=2025-09-24T18:01:30.427Z level=INFO source=sched.go:470 msg="loaded runners" count=1
# time=2025-09-24T18:01:30.427Z level=INFO source=server.go:1251 msg="waiting for llama runner to start responding"
# time=2025-09-24T18:01:30.427Z level=INFO source=ggml.go:487 msg="offloading 24 repeating layers to GPU"
# time=2025-09-24T18:01:30.427Z level=INFO source=ggml.go:493 msg="offloading output layer to GPU"
# time=2025-09-24T18:01:30.427Z level=INFO source=ggml.go:498 msg="offloaded 25/25 layers to GPU"
# time=2025-09-24T18:01:30.442Z level=INFO source=server.go:1285 msg="waiting for server to become available" status="llm server loading model"
# time=2025-09-24T18:02:23.465Z level=INFO source=server.go:1289 msg="llama runner started in 53.68 seconds"
# time=2025-09-24T18:02:23.673Z level=WARN source=runner.go:159 msg="truncating input prompt" limit=4096 prompt=4967 keep=4 new=4096
# [GIN] 2025/09/24 - 18:03:27 | 200 |         1m58s |  184.73.225.134 | POST     "/v1/chat/completions"
